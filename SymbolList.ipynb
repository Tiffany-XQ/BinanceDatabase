# %%
import pandas as pd
import ccxt

exchange = ccxt.binance() 
response = exchange.dapiPublicGetExchangeInfo()['symbols']
info = pd.DataFrame(response)
info.head(6)
# Out:
#           symbol    pair     contractType   deliveryDate    onboardDate  \
# 0    BTCUSD_PERP  BTCUSD        PERPETUAL  4133404800000  1597042800000
# 1  BTCUSD_221230  BTCUSD  CURRENT_QUARTER  1672387200000  1656057600000
# 2  BTCUSD_230331  BTCUSD     NEXT_QUARTER  1680249600000  1664524800000
# 3    ETHUSD_PERP  ETHUSD        PERPETUAL  4133404800000  1597734000000
# 4  ETHUSD_221230  ETHUSD  CURRENT_QUARTER  1672387200000  1656057600000
# 5  ETHUSD_230331  ETHUSD     NEXT_QUARTER  1680249600000  1664524800000
#
#   contractStatus contractSize marginAsset maintMarginPercent  \
# 0        TRADING          100         BTC             2.5000
# 1        TRADING          100         BTC             2.5000
# 2        TRADING          100         BTC             2.5000
# 3        TRADING           10         ETH             2.5000
# 4        TRADING           10         ETH             2.5000
# 5        TRADING           10         ETH             2.5000
#
# ...
